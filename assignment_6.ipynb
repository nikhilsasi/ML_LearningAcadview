# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Reading Weather data set

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %% [markdown]
# ## Checking Datatypes

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
plt.plot([1,2,3,4], linewidth=10.0)
plt.ylabel("Y axis")
plt.xlabel("X axis")
plt.show()

# %%
df["MinTemp"]
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
# 5       6.2
# 6       6.1
# 7       8.3
# 8       8.8
# 9       8.4
# 10      9.1
# 11      8.5
# 12     10.1
# 13     12.1
# 14     10.1
# 15     12.4
# 16     13.8
# 17     11.7
# 18     12.4
# 19     15.6
# 20     15.3
# 21     16.4
# 22     12.8
# 23     12.0
# 24     15.4
# 25     15.6
# 26     13.3
# 27     12.9
# 28     15.1
# 29     13.6
#        ...
# 336     5.6
# 337    16.8
# 338    14.4
# 339    10.3
# 340    11.2
# 341     0.3
# 342     0.5
# 343     0.5
# 344     4.6
# 345     8.2
# 346     4.5
# 347     6.7
# 348    11.9
# 349     9.2
# 350     4.4
# 351     5.0
# 352     6.7
# 353     8.3
# 354    11.3
# 355     9.0
# 356     3.4
# 357     3.2
# 358     0.9
# 359     3.3
# 360     7.9
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %% [markdown]
# ## LINEPLOT GRAPH

# %%
# DIAGRAM 1
plt.plot([df["Pressure9am"],df["MaxTemp"]])
plt.ylabel("MaxTemp")
plt.xlabel("Pressure9am")
# Out:
# Text(0.5,0,'Pressure9am')

# %% [markdown]
# ## SCATTER GRAPH

# %%
# DIAGRAM 2
plt.scatter(df["Pressure9am"],df["MaxTemp"],c="g") 
plt.ylabel("MaxTemp")
plt.xlabel("Pressure9am")
# Out:
# Text(0.5,0,'Pressure9am')

# %% [markdown]
# ## PLOT DIAGRAM OF SHAPE TRIANGLE

# %%
# DIAGRAM 3
plt.plot(df["Pressure9am"],df["MaxTemp"],'r^') 
plt.ylabel("MaxTemp")
plt.xlabel("Pressure9am")
# Out:
# Text(0.5,0,'Pressure9am')

# %% [markdown]
# ## HISTOGRAM GRAPH

# %%
# DIAGRAM 4
plt.hist(df["MinTemp"])
# Out:
# (array([13., 38., 51., 47., 42., 47., 52., 49., 25.,  2.]),
#  array([-5.3 , -2.68, -0.06,  2.56,  5.18,  7.8 , 10.42, 13.04, 15.66,
#         18.28, 20.9 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## DISTPLOT
# seaborn.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None,
#                 hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None,
#                 color=None, vertical=False, norm_hist=False, axlabel=None,
#                 label=None, ax=None)
# kde : bool, optional
#       Whether to plot a gaussian kernel density estimate.

# %%
# DIAGRAM 5
sn.distplot(df["MinTemp"],kde=True)
# Out:
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## DISTPLOT

# %%
# DIAGRAM 6
sn.distplot(df["MinTemp"],kde=False)
# Out:
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## DISTPLOT  GRAPH
# seaborn.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None,
#                 hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None,
#                 color=None, vertical=False, norm_hist=False, axlabel=None,
#                 label=None, ax=None)
# kde : bool, optional
#       Whether to plot a gaussian kernel density estimate.
# hist: bool, optional
#       Whether to plot a (normed) histogram.
# rug : bool, optional
#       Whether to draw a rugplot on the support axis.

# %%
# DIAGRAM 7
sn.distplot(df["MinTemp"],hist=False,kde=True,rug=True)

# %% [markdown]
# ## JOINT PLOT
# seaborn.jointplot(x, y, data=None, kind='scatter', stat_func=<function pearsonr>,color=None,
#                   size=6, ratio=5, space=0.2, dropna=True, xlim=None,ylim=None, joint_kws=None,
#                   marginal_kws=None, annot_kws=None, **kwargs)

# %%
# DIAGRAM 8
sn.jointplot(df["MinTemp"],df["MaxTemp"],color="r")
# Out:
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# DIAGRAM 9
sn.jointplot(df["MinTemp"],df["MaxTemp"],kind="hex", color="r") #hexbin ploT
# Out:
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\NIK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#DIAGRAM 10
sn.jointplot(df["MinTemp"],df["MaxTemp"],kind="kde", color="r")

# %% [markdown]
# ## KDEPLOT GRAPH
# seaborn.kdeplot(data, data2=None, shade=False, vertical=False, kernel='gau',
#                 bw='scott', gridsize=100, cut=3, clip=None, legend=True,
#                 cumulative=False, shade_lowest=True, cbar=False, cbar_ax=None, cbar_kws=None, ax=None, **kwargs)
# shade : bool, optional
#         If True, shade in the area under the KDE curve (or draw with filled contours when data is bivariate).

# %%
# DIAGRAM 11
sn.kdeplot(df["MinTemp"],shade=True, color="r")

# %%
# DIAGRAM 12
plt.figure(figsize=(10,8))
sn.kdeplot(df["MinTemp"],df["MaxTemp"])

# %%
# DIAGRAM 13
plt.figure(figsize=(10,8))  
sn.kdeplot(df["MinTemp"],df["MaxTemp"],shade=True)

# %% [markdown]
# ## LMPLOT
# rn.lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None,
#           size=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None,
#           col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None,
#           x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None,
#           order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None,
#           y_partial=None, truncate=False, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None)
# hue, col, row : strings
#                 Variables that define subsets of the data, which will be drawn on separate facets in the grid.

# %%
#DIAGRAM 14
sn.lmplot(x="MinTemp",y="MaxTemp",data=df,hue="Rainfall")

# %% [markdown]
# ## BOXPLOT GRAPH
# seaborn.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None,
#                 orient=None, color=None, palette=None, saturation=0.75, width=0.8,
#                 dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)

# %%
#DIAGRAM 15
sn.boxplot(x="MinTemp",y="Rainfall",data=df)

# %% [markdown]
# ## STRIPPLOT GRAPH
# seaborn.stripplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None,
#                   jitter=False, dodge=False, orient=None, color=None, palette=None,
#                   size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
# DIAGRAM 16
plt.figure(figsize=(10,8))  
sn.stripplot(x="MinTemp",y="Rainfall",data=df)

# %% [markdown]
# ## COUNTPLOT
# seaborn.countplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None,
#                   color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)¶

# %%
#DIAGRAM 17
sn.countplot(x="MinTemp",data=df)

# %% [markdown]
# ## SWARMPLOT GRAPH
# Seaborn.swarmplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None,
#                   dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
# DIAGRAM 18
plt.figure(figsize=(10,8)) 
sn.swarmplot(x="MinTemp",y="Rainfall",data=df)

# %% [markdown]
# ## HEATMAP
# seaborn.heatmap(data, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None,
#                 fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None,
#                 cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)

# %%
# DIAGRAM 19
plt.figure(figsize=(10,8)) 
corr=df.corr()
sn.heatmap(corr)

# %% [markdown]
# ## PAIRPLOT
# seaborn.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None,
#                  y_vars=None, kind='scatter', diag_kind='hist', markers=None, size=2.5,
#                  aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None)

# %%
tips=sn.load_dataset("tips")
tips.head()

# %%
# DIAGRAM 20
sn.pairplot(tips)

# %%
t1=df["MinTemp"]
t2=df["MaxTemp"]
plt.figure(1)
plt.subplot(211)#numrows numcols fignum
plt.plot(t1,t1,"bo",label="t1")
plt.plot(t2,t2**2,"g",label="t2")
plt.title("subplots")
plt.legend()

plt.subplot(212)#numrows numcols fignum
plt.plot(t2,np.cos(2*np.pi*t2,),"r--")
plt.grid(True)
plt.text(2.18,0.8,r"cos func")
plt.show()
