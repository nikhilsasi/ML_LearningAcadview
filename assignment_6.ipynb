# %%
# DIAGRAM 10
plt.figure(figsize=(10,8))
sn.kdeplot(df["MinTemp"],df["MaxTemp"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c727829334a> in <module>()
#       1 # DIAGRAM 10
# ----> 2 plt.figure(figsize=(10,8))
#       3 sn.kdeplot(df["MinTemp"],df["MaxTemp"])
#
# NameError: name 'plt' is not defined

# %%
# DIAGRAM 11
plt.figure(figsize=(10,8))  
sn.kdeplot(df["MinTemp"],df["MaxTemp"],shade=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-875c98730b9e> in <module>()
#       1 # DIAGRAM 11
# ----> 2 plt.figure(figsize=(10,8))
#       3 sn.kdeplot(df["MinTemp"],df["MaxTemp"],shade=True)
#
# NameError: name 'plt' is not defined

# %%
# DIAGRAM 12
sn.jointplot(df["MinTemp"],df["MaxTemp"],kind="hex", color="r") #hexbin ploT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-65753209c929> in <module>()
#       1 # DIAGRAM 12
# ----> 2 sn.jointplot(df["MinTemp"],df["MaxTemp"],kind="hex", color="r") #hexbin ploT
#
# NameError: name 'sn' is not defined

# %%
#DIAGRAM 13
sn.jointplot(df["MinTemp"],df["MaxTemp"],kind="kde", color="r")

# %%
#DIAGRAM 14
sn.lmplot(x="MinTemp",y="MaxTemp",data=df,hue="Rainfall")

# %%
#DIAGRAM 15
sn.boxplot(x="MinTemp",y="Rainfall",data=df)

# %%
# DIAGRAM 16
plt.figure(figsize=(10,8))  
sn.stripplot(x="MinTemp",y="Rainfall",data=df)

# %%
#DIAGRAM 17
sn.countplot(x="MinTemp",data=df)

# %%
# DIAGRAM 18
plt.figure(figsize=(10,8)) 
sn.swarmplot(x="MinTemp",y="Rainfall",data=df)

# %%
# DIAGRAM 19
plt.figure(figsize=(10,8)) 
corr=df.corr()
sn.heatmap(corr)

# %%
tips=sn.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# DIAGRAM 20
sn.pairplot(tips)

# %%
t1=df["MinTemp"]
t2=df["MaxTemp"]
plt.figure(1)
plt.subplot(211)#numrows numcols fignum
plt.plot(t1,t1,"bo",label="t1")
plt.plot(t2,t2**2,"g",label="t2")
plt.title("subplots")
plt.legend()

plt.subplot(212)#numrows numcols fignum
plt.plot(t2,np.cos(2*np.pi*t2,),"r--")
plt.grid(True)
plt.text(2.18,0.8,r"cos func")
plt.show()

# %%
tips.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d6595c7ab54> in <module>()
# ----> 1 tips.describe()
#
# NameError: name 'tips' is not defined
